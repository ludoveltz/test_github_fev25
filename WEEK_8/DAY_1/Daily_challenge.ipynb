# %% [markdown]
# # STEP 1
#
# ## INPUT TEXT :
# Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.
#
# ## PROMPT :
# "En tant que spécialiste de la communication interne, reformulez ce texte sur la sécurité informatique en un message amical et accessible pour nos collègues. Utilisez des puces, un ton conversationnel, et gardez le tout sous 75 mots. Évitez le jargon technique et mettez l'accent sur les actions concrètes."
#
# ## RÉSULTATS :
#
# 🔐 Petit rappel sympa sur la sécurité !
#
# Hey l'équipe ! Quelques points essentiels pour garder nos données en sécurité :
# • Connectez-vous toujours via notre VPN d'entreprise - c'est votre meilleur allié pour le travail à distance !
# • Utilisez uniquement vos appareils professionnels pour accéder aux données de l'entreprise
# • Un doute ? Contactez notre super équipe IT - ils sont là pour vous aider 😊

# %% [markdown]
# # STEP 2 : Grille d'Évaluation
#
# 1. Relevance ✅
# - Le message conserve les points clés de sécurité essentiels
# - Maintient l'importance du VPN et des appareils sécurisés
# - Garde l'essence de la politique de sécurité
#
# 2. Clarté ✅
# - Langage simple et accessible
# - Termes techniques traduits en concepts compréhensibles
# - Instructions claires et actionnables
#
# 3. Structure ✅
# - Format en points clairs
# - Hiérarchie visuelle efficace
# - Espacement approprié entre les points
#
# 4. Ton ✅
# - Style conversationnel adapté
# - Approche positive et encourageante
# - Ton professionnel mais amical
#
# 5. Longueur ✅
# - Environ 60 mots
# - Reste sous la limite de 75 mots
# - Concis mais complet
#
# 6. Précision Factuelle ⚠️
# Suggestion d'amélioration :
# - Ajouter une mention spécifique sur les "données sensibles"
# - Préciser "VPN approuvé par l'entreprise"

# %% [markdown]
# # STEP 3 :
#
# ## PROMPT RÉVISÉ pour éviter les hallucinations :
#
# "En tant que spécialiste de la communication interne, reformulez ce texte sur la sécurité informatique en :
#
# - Vous limitant STRICTEMENT aux informations présentes dans le texte source
# - Utilisant maximum 2 points clés correspondant aux 2 règles mentionnées
# - Gardant un ton amical mais direct
# - Restant sous 75 mots
# - N'ajoutant AUCUNE information ou ressource non mentionnée dans le texte original"

# %% [markdown]
# # STEP 4 :
#
# ## PROMPT V2 :
# "Transformez ce texte de politique de sécurité en un message ultra-simple et encourageant pour nos stagiaires juniors. Imaginez que vous expliquez à un ami qui débute.
#
# Utilisez :
# - Maximum 4 puces courtes et simples
# - Des mots de tous les jours
# - Un ton positif et rassurant
# - Des exemples concrets du quotidien
# - Aucun jargon technique"
#
# RÉSULTAT :
#
# 👋 Salut les nouveaux !
#
# Petit guide sympa pour protéger nos supers projets :
# • Pense à ton badge virtuel : le VPN ! C'est comme la carte d'accès à nos bureaux, mais pour ton ordi
# • Travaille uniquement sur ton ordinateur pro - comme tu utilises ton badge pro et pas celui d'un ami
# • C'est tout ! Simple non ? 😊

# %% [markdown]
# # STEP 5 :
#
# ## PROMPT POUR L'EXTRACTION DE CITATION :
# "Identifiez la citation la plus importante du texte source qui capture l'essence de la politique de sécurité. La citation doit être :
# - Courte et percutante
# - Autonome (compréhensible sans contexte)
# - Représentative de la règle principale"
#
# CITATION EXTRAITE :
# "Under no circumstances should unsecured connections or personal devices [...] be used to access proprietary data"
#
# ANALYSE :
#
# 1. Quand privilégier la citation ?
# ✅ Situations appropriées :
# - Documents légaux ou de conformité
# - Politiques de sécurité critiques
# - Communications officielles aux partenaires luxe
# - Audits de sécurité
# - Contrats avec les marques de luxe
# - Documentation technique précise
#
# 2. Risques potentiels de la citation :
# ⚠️ Points de vigilance :
# - Peut paraître trop autoritaire/intimidant
# - Risque de confusion avec le jargon technique
# - Peut créer une distance avec les équipes créatives
# - Perte de contexte si mal extraite
# - Peut sembler déconnectée de la culture d'entreprise
# - Risque de mauvaise interprétation sans explication
#
# Recommandation :
# Réserver les citations directes pour les documents officiels et privilégier la reformulation créative pour la communication quotidienne avec les équipes.
