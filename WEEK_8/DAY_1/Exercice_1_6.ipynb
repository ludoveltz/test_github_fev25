# %% [markdown]
# # EXERCICE 1 : "Write something about productivity tips" :
#
# Manque de spécificité :
# - Pas de direction claire ("something")
# - Pas de mention du produit FlowNest
# - Objectif de communication flou
#
# Absence de paramètres de contenu :
# - Public cible non défini
# - Format LinkedIn non spécifié
# - Pas de structure demandée
#
# Manque de contraintes techniques :
# - Longueur non précisée
# - Ton non défini
# - Style d'écriture non spécifié
#
#
# ## PROMPT RÉÉCRIT :
#
# "Agissez en tant que expert en productivité digitale pour créer un post LinkedIn engageant sur FlowNest :
#
# ROLE PROMPTING :
# "Agissez en tant que Responsable Marketing Digital spécialisé en productivité d'entreprise, avec 10 ans d'expérience dans le lancement d'applications SaaS premium. Votre mission est de communiquer sur FlowNest d'une manière qui :
# • Reflète votre expertise approfondie en optimisation du travail
# • Démontre votre compréhension des défis quotidiens des professionnels
# • Partage des conseils basés sur votre expérience concrète
# • Présente FlowNest comme une solution naturelle à ces défis"
#
# INSTRUCTIONS :
# • Rédigez 3 conseils de productivité actionnables
# • Intégrez naturellement les bénéfices de FlowNest
# • Concluez avec un call-to-action clair
#
# FORMAT :
# • Longueur : 1200 caractères maximum
# • Style : professionnel mais accessible
# • Structure : introduction + 3 points + conclusion
# • Incluez des émojis pertinents
#
# TON :
# • Encourageant et expert
# • Solution-oriented
# • Conversationnel mais professionnel"
#
#
# ## LIGNE DE RÉUTILISATION :
#
# "Utilisez cette structure pour tous les posts LinkedIn sur des outils de productivité : hook engageant → 3 conseils actionnables → intégration naturelle du produit → call-to-action clair"

# %% [markdown]
# # EXERCICE 2
#
# ## PROMPT :
# "En tant que professeur de sciences pour élèves de 5ème, créez du contenu pédagogique sur les volcans qui suit les directives ci après :
#
# PARTIE 1 - RÉSUMÉ :
# • Extrayez 2 points clés de l'article
# • Utilisez des mots simples (niveau 11-13 ans)
# • Maximum 2 lignes par point
#
# PARTIE 2 - QUIZ :
# • Créez 3 questions à choix multiples
# • Pour chaque question :
#    - 1 réponse correcte
#    - 2 réponses incorrectes mais plausibles
#    - Évitez les réponses évidentes comme "je ne sais pas"
#
# PARTIE 3 - MISE EN FORME GOOGLE SLIDES :
# • Diapo 1 : Titre + résumé
# • Diapo 2-4 : Une question par diapo
# • Utilisez des puces et numéros clairs
# • Police lisible et grande
#
# TON ET STYLE :
# • Amical mais instructif
# • Comme si vous expliquiez à un petit frère/sœur
# • Pas de termes scientifiques complexes"
#
#
# Comparaison avec "Make a quiz for kids about this article" :
#
# 3 améliorations clés :
#
# 1. Structure claire et organisée
# - Découpage en 3 parties distinctes
# - Instructions précises pour chaque partie
# - Format de présentation défini
#
# 2. Contrôle de la qualité pédagogique
# - Niveau de langue adapté
# - Critères pour les questions/réponses
# - Guidelines pour le ton
#
# 3. Format optimisé pour l'apprentissage
# - Organisation visuelle définie
# - Progression logique du contenu
# - Présentation adaptée à l'âge

# %% [markdown]
# # EXERCICE 3

# %%
import pandas as pd

# Création des données du tableau
data = {
    'Context Type': ['Role', 'Audience', 'Purpose', 'Input Source', 'Format/Style', 'Constraints'],
    'Is it Missing?': ['Yes'] * 6,
    'What Should Be Added?': [
        "Rôle d'analyste financier avec expertise en présentation de données",
        "Équipe de direction, participants à la réunion mensuelle",
        "Mise à jour mensuelle des KPIs financiers clés",
        "Rapport financier mensuel avec données quantitatives",
        "Format présentation orale de 3 minutes",
        "Maximum 3 points clés, chiffres essentiels uniquement"
    ]
}

# Création du DataFrame
df = pd.DataFrame(data)

# Configuration de l'affichage
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# Affichage du tableau
print(df.to_string(index=False))
# Out:
# Context Type Is it Missing?                                               What Should Be Added?
#         Role            Yes Rôle d'analyste financier avec expertise en présentation de données
#     Audience            Yes            Équipe de direction, participants à la réunion mensuelle
#      Purpose            Yes                      Mise à jour mensuelle des KPIs financiers clés
# Input Source            Yes                Rapport financier mensuel avec données quantitatives
# Format/Style            Yes                              Format présentation orale de 3 minutes
#  Constraints            Yes               Maximum 3 points clés, chiffres essentiels uniquement

# %% [markdown]
# PROMPT RÉÉCRIT :
#
# "En tant qu'analyste financier senior, créez un résumé structuré de ce rapport financier mensuel qui :
#
# CONTEXTE :
# • Pour : équipe de direction non-technique
# • Format : présentation orale de 3 minutes
# • Objectif : mise à jour mensuelle des performances financières
#
# STRUCTURE REQUISE :
# • 3 points clés maximum
# • Chaque point doit inclure :
#    - Un chiffre clé comparé au mois précédent
#    - Une brève explication de l'impact
#    - Une tendance ou projection
#
# FORMAT :
# • Phrases courtes et directes
# • Vocabulaire accessible aux non-financiers
# • Ordre : du plus important au moins critique
#
# CONTRAINTES :
# • Durée totale : 3 minutes maximum
# • Focus sur les métriques essentielles uniquement
# • Éviter le jargon financier complexe"

# %% [markdown]
# # EXERCICE 4
#
# Style choisi : CONVERSATIONNEL
#
# PROMPT :
#
# "En tant qu'assistant de support client e-commerce, interagissez avec les clients selon ces directives :
#
# ACCUEIL :
# • Saluez poliment le client
# • Demandez en quoi vous pouvez aider
# • Montrez votre disponibilité immédiate
#
# DIALOGUE :
# • Écoutez attentivement la demande
# • Reformulez pour confirmer la compréhension
# • Proposez des solutions adaptées
# • Vérifiez la satisfaction
#
# TON :
# • Amical mais professionnel
# • Patient et compréhensif
# • Rassurant et positif"
#
#
# CARACTÉRISTIQUES CLÉS du style conversationnel :
#
# 1. Dialogue naturel
# - Flux de conversation fluide
# - Échanges interactifs
# - Adaptation au contexte
#
# 2. Approche humaine
# - Ton empathique
# - Réponses personnalisées
# - Suivi de satisfaction
#
#
# JUSTIFICATION DU CHOIX :
#
# 1. VS Exploratory
# - Support client nécessite des réponses précises
# - Pas besoin de brainstorming
#
# 2. VS Structured
# - Trop rigide pour le service client
# - Manque de flexibilité
#
# 3. VS Functional
# - Trop mécanique
# - Manque de chaleur humaine
#
# Le style conversationnel est idéal car il :
# ✓ Humanise l'interaction
# ✓ Rassure le client
# ✓ Facilite la résolution des problèmes
# ✓ Améliore l'expérience client

# %% [markdown]
# # EXERCICE 5
#
# ## PROMPT INITIAL :
#
# "Créez un texte promotionnel pour la montre connectée PulseOne Mini en respectant STRICTEMENT ces règles :
#
# CONTRAINTES ABSOLUES :
# • Maximum 50 mots - pas un mot de plus
# • Exactement 3 puces - une pour chaque fonctionnalité
# • Mentionner OBLIGATOIREMENT : autonomie, suivi fitness, connectivité Bluetooth
#
# TON :
# • Amical et enthousiaste
# • Comme un ami qui recommande un produit
# • Utiliser 'vous' pour parler au lecteur
#
# FORMAT :
# • Introduction d'une ligne
# • 3 puces courtes
# • Pas de conclusion"
#
#
# RÉSULTAT TEST :
#
# Découvrez votre nouveau compagnon bien-être !
#
# • Une autonomie impressionnante de 5 jours pour vous accompagner sans interruption
# • Suivez tous vos objectifs fitness avec 12 modes d'entraînement personnalisés
# • Connectivité Bluetooth instantanée pour rester connecté à votre smartphone
#
#
# ÉVALUATION :
#
# 1. Respect du nombre de mots ✅
# - 42 mots (sous la limite de 50)
# - Format concis respecté
#
# 2. Mention des 3 fonctionnalités ✅
# - Autonomie ✓
# - Suivi fitness ✓
# - Bluetooth ✓
#
# 3. Ton amical et engageant ✅
# - Utilisation du "vous"
# - Ton positif
# - Vocabulaire accessible
#
#
# ## PROMPT RÉVISÉ avec contraintes renforcées :
#
# "Créez un texte promotionnel pour la PulseOne Mini en suivant ces règles NON NÉGOCIABLES :
#
# CONTRAINTES STRICTES :
# • MAXIMUM 50 mots - ARRÊTEZ d'écrire à 50 mots
# • EXACTEMENT 3 puces - ni plus ni moins
# • OBLIGATOIRE dans cet ordre :
#    1. Autonomie de la batterie
#    2. Fonctions fitness
#    3. Compatibilité Bluetooth
#
# TON ET STYLE :
# • Ton amical et direct
# • Phrases courtes et dynamiques
# • Utilisez 'vous' et '!'
#
# FORMAT :
# • Une ligne d'introduction (max 10 mots)
# • 3 puces (max 13 mots chacune)
# • Pas de phrase de conclusion"

# %% [markdown]
# # EXERCICE 6
#
# ## PROMPT OPTIMISÉ ANTI-HALLUCINATION :
# "Résumez cet article scientifique sur le changement climatique et la biodiversité marine en suivant ces règles STRICTES :
#
# RÈGLES DE VÉRIFICATION :
# • Citez UNIQUEMENT les informations explicitement présentes dans l'article
# • Pour chaque donnée chiffrée, indiquez le paragraphe source
# • Si une information semble incertaine, écrivez clairement 'Non mentionné dans l'article'
#
# FORMAT REQUIS :
# • Commencez chaque fait par 'L'article indique que...'
# • Utilisez des guillemets pour les citations directes
# • Ajoutez [Source non trouvée] après toute information non vérifiable
#
# INTERDICTIONS :
# • Pas d'extrapolation de données
# • Pas de conclusions personnelles
# • Pas de statistiques non citées"
#
#
# ## 2 STRATÉGIES DE MITIGATION :
#
# 1. Traçabilité systématique
# - Citation obligatoire des sources
# - Marquage explicite des incertitudes
# - Référencement des paragraphes
#
# 2. Langage de vérification
# - Formulations conditionnelles
# - Distinction claire entre faits et hypothèses
# - Vocabulaire de précaution
#
#
# ## 2 DOMAINES À RISQUE :
#
# 1. Domaine médical
# Pourquoi risqué :
# - Impact direct sur la santé des patients
# - Décisions critiques basées sur les informations
# - Conséquences potentiellement mortelles
# - Responsabilité légale importante
#
# 2. Domaine juridique
# Pourquoi risqué :
# - Base pour des décisions judiciaires
# - Impact sur les droits des personnes
# - Précédents juridiques
# - Conséquences financières majeures
