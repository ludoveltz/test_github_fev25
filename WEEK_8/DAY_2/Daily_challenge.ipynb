# %% [markdown]
# ## Étape 1 : Prompt de Résumé Initial
#
# Prompt Few-Shot avec Chain-of-Thought :
#
# En tant qu'expert en analyse de contrats, résumez ce document en suivant cette structure :
#
# Exemple de format :
# 1. Parties concernées : [Qui sont les parties]
# 2. Obligations principales : [Responsabilités clés]
# 3. Conditions financières : [Termes de paiement]
# 4. Clauses importantes : [Durée, résiliation, confidentialité]
#
# Analysons ce contrat étape par étape :
#
# 1. Identification des parties :
# - Prestataire : BrightLine Technologies Ltd.
# - Client : NovaWare Systems Inc.
# - Date d'effet : 1er mars 2025
#
# 2. Obligations principales :
# - Services de gestion d'infrastructure cloud
# - Surveillance et réponse aux incidents
# - Rapports mensuels
# - Détails dans l'Annexe A
#
# 3. Conditions financières :
# - Frais mensuels fixes : 12 000 $
# - Délai de paiement : 30 jours
# - Pénalité de retard : 2% par mois
#
# 4. Clauses importantes :
# - Durée : 12 mois (jusqu'au 1er mars 2026)
# - Préavis de résiliation : 30 jours
# - Limitation de responsabilité : plafonnée aux frais des 3 derniers mois
# - Confidentialité : protection mutuelle des informations sensibles
# - Droit applicable : État de Californie
#
#
# ## Étape 2 : Prompt Basé sur le Rôle
#
# Vous êtes un avocat spécialisé en droit des contrats avec 15 ans d'expérience. Votre rôle est d'expliquer les clauses de ce contrat de manière claire et précise.
#
# Pour chaque question :
# 1. Identifiez la clause pertinente
# 2. Expliquez en langage simple
# 3. Soulignez les implications pratiques
# 4. Suggérez des points d'attention
#
# Format de réponse :
# - Clause concernée : [citation]
# - Explication : [analyse en langage simple]
# - Implications : [conséquences pratiques]
# - Points d'attention : [risques ou opportunités]
#
#
# ## Étape 3 : Intégration de la Mémoire
#
# Structure de stockage du contexte :
#
# Avantages de cette Approche
# - Organisation claire des informations
# - Facilité de récupération du contexte pertinent
# - Traçabilité des interprétations précédentes
# - Maintien de la cohérence dans les réponses
#
# Pourquoi pas les autres méthodes ?
# - Prior message passing : Trop simple pour un contrat complexe
# - Vector store retrieval : Trop complexe pour ce cas d'usage spécifique
#
# json
# {
#     "document_summary": {
#         "parties": {...},
#         "obligations": {...},
#         "financial_terms": {...},
#         "key_clauses": {...}
#     },
#     "conversation_history": [
#         {
#             "timestamp": "2025-04-01 11:57",
#             "question": "...",
#             "answer": "...",
#             "context_used": [...]
#         }
#     ],
#     "legal_interpretations": {
#         "liability": {...},
#         "termination": {...},
#         "confidentiality": {...}
#     }
# }
#
#
# ## Étape 4 : Auto-réflexion et Atténuation
#
# Prompt d'auto-réflexion :
#
# Après chaque réponse, vérifiez :
#
# 1. Exactitude juridique
# - La réponse est-elle conforme au texte du contrat ?
# - Y a-t-il des interprétations discutables ?
#
# 2. Clarté
# - L'explication est-elle compréhensible ?
# - Les termes techniques sont-ils bien définis ?
#
# 3. Exhaustivité
# - Tous les aspects pertinents sont-ils couverts ?
# - Manque-t-il des informations importantes ?
#
# 4. Implications pratiques
# - Les conséquences sont-elles clairement expliquées ?
# - Les risques sont-ils correctement identifiés ?
#
# Format de révision :
# ✓ Points confirmés :
# ⚠️ Points à clarifier :
# 📝 Suggestions d'amélioration :
