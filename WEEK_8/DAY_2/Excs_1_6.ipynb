# %% [markdown]
# # EXERCICE 1
#
# 1. Dans le prompt original, l'erreur se trouve dans le calcul de la soustraction :
# $5.00 - $4.75 = $0.50 est incorrect
# La véritable soustraction devrait être :
# $5.00 - $4.75 = $0.25
#
# 2. Réécriture du Prompt avec Chain-of-Thought Correct ✏️
# Un magasin vend des crayons à $0.75 l'unité. Si Alice achète 6 crayons et paie avec un billet de $5, combien reçoit-elle de monnaie ? Résolvons cela étape par étape.
#
# 1. Calculons d'abord le coût total des crayons :
#    - Prix par crayon = $0.75
#    - Nombre de crayons = 6
#    - Coût total = 6 × $0.75 = $4.75
#
# 2. Calculons maintenant la monnaie :
#    - Argent donné = $5.00
#    - Coût total = $4.75
#    - Monnaie = $5.00 - $4.75 = $0.25
#
# 3. Réponse Correcte 💡
# Alice doit recevoir $0.25 de monnaie.

# %% [markdown]
# # EXERCICE 2
#
# Choix de la Stratégie : Few-Shot Prompting pour Classification de Support Client
#
# Justification :
# - Besoin de catégoriser précisément les demandes
# - Cas d'usage répétitifs et bien définis
# - Importance de la cohérence dans les réponses
# - Nécessité d'exemples clairs pour la classification
#
# Exemple de Prompt :
# Catégorisez chaque message client dans l'une des catégories suivantes :
# - Problème de Facturation
# - Support Technique
# - Accès au Compte
# - Autre
#
# Voici des exemples :
#
# Message : "Je n'ai pas reçu ma facture du mois dernier."
# Catégorie : Problème de Facturation
#
# Message : "Mon application ne se lance plus depuis la mise à jour."
# Catégorie : Support Technique
#
# Message : "J'ai oublié mon mot de passe et je ne peux pas me connecter."
# Catégorie : Accès au Compte
#
# Message : "Quels sont vos horaires d'ouverture ?"
# Catégorie : Autre
#
# Maintenant, catégorisez ce message :
# [Message client à catégoriser]"
#
#
# Pourquoi cette approche est optimale :
#
# 1. Clarté
# - Exemples concrets pour chaque catégorie
# - Structure simple et répétitive
# - Classifications non ambiguës
#
# 2. Cohérence
# - Format standardisé
# - Exemples représentatifs
# - Catégories mutuellement exclusives
#
# 3. Généralisation
# - Couvre les cas d'usage principaux
# - Facilement adaptable à de nouveaux messages
# - Permet une classification rapide et précise
#
# Cette approche permet au chatbot de :
# - Classifier efficacement les demandes
# - Maintenir une cohérence dans les réponses
# - Diriger les clients vers le bon service
# - Optimiser le processus de support

# %% [markdown]
# # EXERCICE 3
#
# Prompt AlignedCoT :
#
# Calculons le coût total des pots de fleurs en utilisant deux approches différentes.
#
# Chemin de Raisonnement 1 : Calcul par taille
# 1. Pots petits : 2 × $2 = $4
# 2. Pots moyens : 3 × $4 = $12
# 3. Pots larges : 1 × $6 = $6
# 4. Total : $4 + $12 + $6 = $22
#
# Chemin de Raisonnement 2 : Calcul par quantité totale et prix unitaire
# 1. Nombre total de pots : 2 + 3 + 1 = 6 pots
# 2. Prix par type :
#    - Petits (2 pots) : 2 × $2 = $4
#    - Moyens (3 pots) : 3 × $4 = $12
#    - Grand (1 pot) : 1 × $6 = $6
# 3. Total : $4 + $12 + $6 = $22
#
# Comparaison et Vérification :
# - Les deux chemins de raisonnement arrivent au même résultat : $22
# - Les calculs sont cohérents et logiques dans les deux cas
#
# Conclusion : Le coût total est de $22, confirmé par deux méthodes de calcul différentes.

# %% [markdown]
# # Exercice 4
#
# Pipeline de Traitement en Trois Étapes
#
# 1️⃣ ÉTAPE 1 : Identification du Domaine
#
# Prompt Template :
# Analysez le document suivant et identifiez son domaine principal parmi :
# - Intelligence Artificielle Générative
# - Design & Innovation Luxe
# - Technologie & Workflows Créatifs
# - Autre
#
# Contexte précédent : {contexte_précédent}
# Document à analyser : {texte_document}
#
# Répondez sous la forme :
# Domaine principal : [domaine]
# Sous-domaines : [liste des sous-domaines pertinents]
#
#
# 2️⃣ ÉTAPE 2 : Extraction des Contributions Principales
#
# Prompt Template :
# En vous basant sur le domaine identifié ({domaine}), extrayez les contributions principales de ce document.
#
# Focus sur :
# - Innovations techniques
# - Méthodologies proposées
# - Résultats quantifiables
# - Applications pratiques
#
# Format de réponse :
# 1. Contribution principale : [description]
#    Impact : [analyse]
# 2. Contribution secondaire : [description]
#    Impact : [analyse]
# ...
#
#
# 3️⃣ ÉTAPE 3 : Génération de Questions de Recherche
#
# Prompt Template :
# Basé sur :
# - Domaine : {domaine}
# - Contributions principales : {contributions}
# - Contexte actuel du secteur
#
# Générez 3 questions de recherche pertinentes pour approfondir ces travaux.
#
# Format :
# Q1 : [question]
#    Justification : [pourquoi cette direction est prometteuse]
# Q2 : [question]
#    Justification : [pourquoi cette direction est prometteuse]
# Q3 : [question]
#    Justification : [pourquoi cette direction est prometteuse]
#
#
# 🔄 Logique Conditionnelle et Chaînage de Contexte
#
# 1. Points de Décision :
# - Si domaine = "IA Générative" → Accent sur aspects techniques
# - Si domaine = "Design Luxe" → Focus sur applications créatives
# - Si domaine = "Workflows" → Priorité aux aspects opérationnels
#
# 2. Chaînage de Contexte :
# - Transmission du domaine identifié à l'étape 2
# - Utilisation des contributions pour guider l'étape 3
# - Maintien de la cohérence thématique
#
# 3. Adaptations Dynamiques :
# - Ajustement des prompts selon le type de document
# - Personnalisation des questions selon le contexte
# - Évolution des templates selon les retours
#
# Cette structure permet un traitement systématique tout en maintenant la flexibilité nécessaire pour différents types de documents de recherche.

# %% [markdown]
# # EXERCICE 5
#
# ## Version 1 : Prompt Basique (Potentiellement Biaisé)
#
# En fonction du profil suivant, suggérez 3 carrières possibles :
# - Formation : Master en technologie
# - Intérêts : Créativité, innovation
# - Compétences : Python, design, gestion de projet
#
# Recommandez les meilleures carrières pour cette personne.
#
#
# ⚠️ Problèmes potentiels de ce prompt :
# - Peut conduire à des stéréotypes de genre
# - Risque de biais basés sur des présupposés culturels
# - Manque de cadre pour l'équité
#
#
# ## Version 2 : Prompt avec Rôle (Réduction des Biais)
#
# Vous êtes un conseiller d'orientation professionnel expert, formé spécifiquement pour :
# - Évaluer objectivement les compétences sans considération de genre, âge ou origine
# - Baser les recommandations uniquement sur les capacités et intérêts
# - Proposer des parcours innovants et diversifiés
#
# Analysez le profil suivant de manière objective :
# - Formation : Master en technologie
# - Intérêts : Créativité, innovation
# - Compétences : Python, design, gestion de projet
#
# Pour chaque recommandation de carrière :
# 1. Listez les compétences requises qui correspondent
# 2. Expliquez le lien avec les intérêts mentionnés
# 3. Identifiez les opportunités de développement
# 4. Évitez toute supposition basée sur des stéréotypes
#
# Format de réponse :
# Carrière 1 :
# - Titre :
# - Correspondance compétences :
# - Lien avec intérêts :
# - Opportunités :
#
# [Répéter pour 2 autres suggestions]
#
#
# Améliorations apportées par le prompt avec rôle :
#
# 1. Cadre Objectif
# - Instructions explicites pour éviter les biais
# - Focus sur les compétences plutôt que les caractéristiques personnelles
# - Structure d'évaluation standardisée
#
# 2. Transparence
# - Justification claire des recommandations
# - Lien explicite entre compétences et suggestions
# - Processus de décision documenté
#
# 3. Équité
# - Évaluation basée sur des critères mesurables
# - Diversité dans les suggestions
# - Absence de présupposés démographiques
#
# 4. Professionnalisme
# - Approche structurée et méthodique
# - Recommandations basées sur des faits
# - Vision holistique du développement de carrière

# %% [markdown]
# # EXERCICE 6
#
# Technique Choisie : Stockage Vectoriel (Vector Store Retrieval)
# Cette approche permet une recherche sémantique efficace des interactions précédentes.
#
# 📝 Structure du Contexte Historique :
# ```json
# {
#     "user_preferences": {
#         "sleep_schedule": {
#             "bedtime": "23:00",
#             "wakeup": "07:00",
#             "sleep_issues": ["difficulté d'endormissement"]
#         },
#         "diet": {
#             "restrictions": ["végétarien"],
#             "goals": ["plus de protéines"],
#             "allergies": []
#         },
#         "exercise": {
#             "preferred_activities": ["course", "yoga"],
#             "frequency": "3x par semaine",
#             "limitations": ["douleur genou droit"]
#         }
#     },
#     "previous_advice": [
#         {
#             "date": "2025-03-30",
#             "topic": "sommeil",
#             "advice": "Établir une routine de méditation avant le coucher"
#         },
#         {
#             "date": "2025-03-31",
#             "topic": "alimentation",
#             "advice": "Augmenter les légumineuses pour les protéines"
#         }
#     ]
# }
#
#
# Prompt avec Intégration du Contexte :
#
# Vous êtes un coach santé virtuel avec accès à l'historique des interactions du client.
#
# Contexte précédent :
# - Profil sommeil : Coucher 23h, réveil 7h, difficulté d'endormissement
# - Régime : Végétarien, objectif protéines
# - Exercice : Course et yoga, 3x/semaine, attention genou droit
# - Dernier conseil : Méditation avant coucher (30/03), légumineuses (31/03)
#
# Question actuelle du client : "Je me sens fatigué après mes séances de course. Des conseils ?"
#
# Pour votre réponse :
# 1. Référencez les informations pertinentes du contexte
# 2. Assurez la cohérence avec les conseils précédents
# 3. Prenez en compte les restrictions connues (genou, régime)
# 4. Proposez des recommandations personnalisées
#
# Format de réponse :
# - Analyse de la situation (basée sur l'historique)
# - Recommandation principale
# - Lien avec les conseils précédents
# - Suggestions de suivi
#
#
# 💡 Avantages de cette Approche :
#
# 1. Personnalisation
# - Utilise l'historique complet des interactions
# - Prend en compte les préférences spécifiques
# - Adapte les conseils aux contraintes
#
# 2. Cohérence
# - Maintient une continuité dans les recommandations
# - Évite les conseils contradictoires
# - Suit la progression du client
#
# 3. Contextualisation
# - Intègre les informations précédentes naturellement
# - Permet des références pertinentes
# - Crée une expérience conversationnelle fluide
