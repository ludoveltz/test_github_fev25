# %%
import pandas as pd
from IPython.display import display, HTML

# Création des données pour le tableau
data = {
    'Aspect': [
        'Généralisation Améliorée',
        'Réduction des Données Étiquetées',
        'Fine-tuning Rapide',
        'Transfer Learning',
        'Robustesse',
        'Biais Potentiels',
        'Désinformation',
        'Risques d\'Usage Abusif',
        'Stratégies d\'Atténuation'
    ],
    'Bénéfices/Risques': [
        "• Meilleure performance sur nouvelles tâches\n• Capture de patterns universels\n• Compréhension contextuelle approfondie\n• Adaptation cross-domaine",
        "• Réduction de 90% des données nécessaires\n• Économie de ressources d'annotation\n• Démarrage rapide des projets\n• Démocratisation de l'IA",
        "• Adaptation en quelques heures/jours\n• Moins de ressources computationnelles\n• Itérations rapides\n• Validation accélérée",
        "• Réutilisation des connaissances\n• Adaptation multi-domaines\n• Apprentissage efficace\n• Optimisation des ressources",
        "• Stabilité accrue\n• Résistance au bruit\n• Performance consistante\n• Fiabilité améliorée",
        "• Biais sociétaux hérités\n• Sous-représentation de groupes\n• Stéréotypes renforcés\n• Discrimination potentielle",
        "• Propagation de fausses informations\n• Contenu généré trompeur\n• Confusion source/vérité\n• Impact sociétal",
        "• Génération de contenu malveillant\n• Manipulation d'opinion\n• Automatisation d'attaques\n• Violation de privacy",
        "• Audits réguliers des données\n• Filtrage éthique\n• Gouvernance transparente\n• Formation responsable"
    ],
    'Stratégies et Implications': [
        "• Validation croisée rigoureuse\n• Tests sur données diverses\n• Monitoring des performances\n• Documentation des limites",
        "• Sélection données qualitatives\n• Validation experte\n• Échantillonnage stratifié\n• Métriques de qualité",
        "• Protocoles d'optimisation\n• Benchmarks standardisés\n• Validation continue\n• Contrôle qualité",
        "• Cadre éthique strict\n• Traçabilité des adaptations\n• Évaluation d'impact\n• Documentation exhaustive",
        "• Tests de stress systématiques\n• Évaluation adversariale\n• Monitoring continu\n• Maintenance préventive",
        "• Diversification des données\n• Audit de biais\n• Correction active\n• Formation éthique",
        "• Fact-checking automatisé\n• Sources vérifiées\n• Transparence totale\n• Mécanismes de correction",
        "• Contrôles d'accès stricts\n• Monitoring d'usage\n• Limites d'utilisation\n• Responsabilité légale",
        "• Formation continue\n• Comité d'éthique\n• Guidelines claires\n• Révision régulière"
    ]
}

# Création du DataFrame
df = pd.DataFrame(data)

# Style du tableau
styles = [
    dict(selector="th", props=[("font-weight", "bold"),
                              ("text-align", "left"),
                              ("background-color", "#2c3e50"),
                              ("color", "white"),
                              ("padding", "12px")]),
    dict(selector="td", props=[("padding", "12px"),
                              ("white-space", "pre-wrap"),
                              ("border-bottom", "1px solid #ddd")]),
    dict(selector="caption", props=[("caption-side", "top"),
                                  ("font-size", "1.2em"),
                                  ("margin-bottom", "10px"),
                                  ("color", "#2c3e50")])
]

# Création du tableau stylisé
styled_df = df.style\
    .set_table_styles(styles)\
    .set_properties(**{
        'white-space': 'pre-wrap',
        'text-align': 'left',
        'padding': '12px',
        'background-color': '#ffffff'
    })\
    .set_caption("Analyse des Bénéfices et Considérations Éthiques des Modèles Pré-entraînés")

# Affichage du tableau
display(styled_df)
# Out:
# <style type="text/css">
# #T_52564 th {
#   font-weight: bold;
#   text-align: left;
#   background-color: #2c3e50;
#   color: white;
#   padding: 12px;
# }
# #T_52564 td {
#   padding: 12px;
#   white-space: pre-wrap;
#   border-bottom: 1px solid #ddd;
# }
# #T_52564 caption {
#   caption-side: top;
#   font-size: 1.2em;
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_52564_row0_col0, #T_52564_row0_col1, #T_52564_row0_col2, #T_52564_row1_col0, #T_52564_row1_col1, #T_52564_row1_col2, #T_52564_row2_col0, #T_52564_row2_col1, #T_52564_row2_col2, #T_52564_row3_col0, #T_52564_row3_col1, #T_52564_row3_col2, #T_52564_row4_col0, #T_52564_row4_col1, #T_52564_row4_col2, #T_52564_row5_col0, #T_52564_row5_col1, #T_52564_row5_col2, #T_52564_row6_col0, #T_52564_row6_col1, #T_52564_row6_col2, #T_52564_row7_col0, #T_52564_row7_col1, #T_52564_row7_col2, #T_52564_row8_col0, #T_52564_row8_col1, #T_52564_row8_col2 {
#   white-space: pre-wrap;
#   text-align: left;
#   padding: 12px;
# ...
