# %%
import pandas as pd
from IPython.display import display, HTML

# Création du tableau des scénarios
data_scenarios = {
    'Scénario': [
        'Analyse sentiment temps réel (mobile)',
        'Recherche documents juridiques',
        'Support client multilingue',
        'Pré-entraînement efficace',
        'Environnement ressources limitées'
    ],
    'Modèle Recommandé': [
        'DistilBERT',
        'RoBERTa',
        'XLM-RoBERTa',
        'ELECTRA',
        'ALBERT'
    ],
    'Justification': [
        "• Taille réduite (40% plus petit)\n• Performance temps réel\n• Adapté aux appareils mobiles\n• Bon équilibre précision/rapidité",
        "• Précision maximale\n• Robustesse accrue\n• Meilleure gestion du contexte\n• Optimisé pour textes longs",
        "• Support 100+ langues\n• Performances cross-lingues\n• Transfert apprentissage efficace\n• Adaptation culturelle",
        "• Détection efficace remplacements\n• Pré-entraînement optimisé\n• Apprentissage discriminatif\n• Meilleure convergence",
        "• Architecture légère\n• Paramètres partagés\n• Efficacité computationnelle\n• Performance préservée"
    ]
}

df_scenarios = pd.DataFrame(data_scenarios)

# Style du tableau
styles = [
    dict(selector="th", props=[("font-weight", "bold"),
                              ("text-align", "left"),
                              ("background-color", "#2c3e50"),
                              ("color", "white"),
                              ("padding", "12px")]),
    dict(selector="td", props=[("padding", "12px"),
                              ("white-space", "pre-wrap"),
                              ("border-bottom", "1px solid #ddd")])
]

styled_df_scenarios = df_scenarios.style\
    .set_table_styles(styles)\
    .set_properties(**{
        'white-space': 'pre-wrap',
        'text-align': 'left',
        'padding': '12px',
        'background-color': '#ffffff'
    })\
    .set_caption("Analyse des Scénarios par Variation BERT")

display(styled_df_scenarios)

# Tableau comparatif détaillé
data_comparison = {
    'Caractéristiques': [
        'Données Entraînement',
        'Taille du Modèle',
        'Optimisations Spécifiques',
        'Cas d\'Usage Idéaux',
        'Performance Relative'
    ],
    'RoBERTa': [
        "• 160GB de données\n• Nettoyage amélioré\n• Sans NSP",
        "• Large (355M params)\n• Empreinte mémoire importante",
        "• Dynamic masking\n• Longer training\n• Larger batches",
        "• Analyse précise\n• Textes complexes\n• Recherche",
        "• SOTA sur GLUE\n• Excellente précision\n• Coût élevé"
    ],
    'ALBERT': [
        "• Même que BERT\n• Factorisation matrices\n• SOP au lieu de NSP",
        "• Compact (12M-18M params)\n• Paramètres partagés",
        "• Factorisation embeddings\n• Cross-layer sharing\n• SOP task",
        "• Resources limitées\n• Long texts\n• Haute efficacité",
        "• Proche BERT\n• Efficace\n• Économique"
    ],
    'DistilBERT': [
        "• Distillation de BERT\n• Données optimisées",
        "• 40% plus petit\n• Rapide",
        "• Knowledge distillation\n• Token-type embeddings\n• Cosine loss",
        "• Mobile\n• Temps réel\n• Edge computing",
        "• 95% BERT\n• 60% plus rapide\n• Léger"
    ],
    'ELECTRA': [
        "• Approche GAN-like\n• Token replacement",
        "• Variable (petit à grand)\n• Flexible",
        "• Replaced token detection\n• Discriminative learning\n• Efficient training",
        "• Pré-entraînement\n• Détection anomalies\n• Classification",
        "• Supérieure à BERT\n• Training efficace\n• Adaptable"
    ],
    'XLM-RoBERTa': [
        "• 2.5TB multilingue\n• 100+ langues",
        "• Large (355M params)\n• Multilingue",
        "• Cross-lingual training\n• Improved tokenization\n• Cultural adaptation",
        "• International\n• Traduction\n• Support global",
        "• Leader multilingue\n• Transfert cross-langue\n• Universel"
    ]
}

df_comparison = pd.DataFrame(data_comparison)

styled_df_comparison = df_comparison.style\
    .set_table_styles(styles)\
    .set_properties(**{
        'white-space': 'pre-wrap',
        'text-align': 'left',
        'padding': '12px',
        'background-color': '#ffffff'
    })\
    .set_caption("Comparaison Détaillée des Variations BERT")

display(styled_df_comparison)
# Out:
# <style type="text/css">
# #T_ee249 th {
#   font-weight: bold;
#   text-align: left;
#   background-color: #2c3e50;
#   color: white;
#   padding: 12px;
# }
# #T_ee249 td {
#   padding: 12px;
#   white-space: pre-wrap;
#   border-bottom: 1px solid #ddd;
# }
# #T_ee249_row0_col0, #T_ee249_row0_col1, #T_ee249_row0_col2, #T_ee249_row1_col0, #T_ee249_row1_col1, #T_ee249_row1_col2, #T_ee249_row2_col0, #T_ee249_row2_col1, #T_ee249_row2_col2, #T_ee249_row3_col0, #T_ee249_row3_col1, #T_ee249_row3_col2, #T_ee249_row4_col0, #T_ee249_row4_col1, #T_ee249_row4_col2 {
#   white-space: pre-wrap;
#   text-align: left;
#   padding: 12px;
#   background-color: #ffffff;
# }
# </style>
# <table id="T_ee249">
#   <caption>Analyse des Scénarios par Variation BERT</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee249_level0_col0" class="col_heading level0 col0" >Scénario</th>
# ...
