# %%
import pandas as pd
from IPython.display import display, HTML

# Création des données pour le tableau
data = {
    'Aspect': [
        'Feature Engineering',
        'Word Representations',
        'Model Architectures',
        'Training Methodology',
        'Key Examples',
        'Advantages',
        'Disadvantages'
    ],
    'NLP Traditionnel': [
        "• Manuel et laborieux\n• Extraction manuelle des caractéristiques\n• Règles linguistiques prédéfinies\n• Nécessite une expertise approfondie du domaine",
        "• Bag of Words (BoW)\n• TF-IDF\n• Word2Vec statique\n• GloVe\n• Représentations fixes",
        "• Modèles statistiques\n• Règles manuelles\n• Réseaux peu profonds\n• Maximum Entropy\n• Architectures séquentielles simples",
        "• Entraînement par tâche\n• Supervision complète\n• Données limitées\n• Pas de transfert d'apprentissage\n• Spécifique au domaine",
        "• Naïve Bayes\n• SVM\n• Hidden Markov Models\n• CRF\n• Decision Trees",
        "• Interprétabilité claire\n• Ressources limitées requises\n• Contrôle précis\n• Debuggable\n• Prévisible",
        "• Performance limitée\n• Peu évolutif\n• Dépendant du domaine\n• Maintenance coûteuse\n• Rigidité"
    ],
    'NLP Moderne': [
        "• Automatique via deep learning\n• Apprentissage des features de bout en bout\n• Extraction autonome des caractéristiques\n• Capacité d'adaptation contextuelle",
        "• BERT embeddings\n• GPT embeddings\n• Embeddings contextuels\n• Représentations dynamiques\n• Attention bidirectionnelle",
        "• Transformers\n• Architectures profondes\n• Attention multi-têtes\n• Encodeur-décodeur\n• Architectures massivement parallèles",
        "• Pré-entraînement à grande échelle\n• Fine-tuning spécifique\n• Apprentissage par transfert\n• Few-shot learning\n• Zero-shot capabilities",
        "• BERT et variantes\n• GPT series\n• T5\n• RoBERTa\n• XLNet",
        "• Performance supérieure\n• Généralisation puissante\n• Adaptabilité multi-tâches\n• Capture de nuances\n• Robustesse",
        "• Ressources computationnelles importantes\n• Opacité (boîte noire)\n• Biais potentiels\n• Coût énergétique\n• Complexité d'implémentation"
    ]
}

# Création du DataFrame
df = pd.DataFrame(data)

# Style du tableau
styles = [
    dict(selector="th", props=[("font-weight", "bold"),
                              ("text-align", "left"),
                              ("background-color", "#f2f2f2"),
                              ("padding", "10px")]),
    dict(selector="td", props=[("padding", "10px"),
                              ("white-space", "pre-wrap")]),
    dict(selector="caption", props=[("caption-side", "top")])
]

# Création du tableau stylisé
styled_df = df.style\
    .set_table_styles(styles)\
    .set_properties(**{
        'white-space': 'pre-wrap',
        'text-align': 'left',
        'padding': '10px'
    })\
    .set_caption("Comparaison entre NLP Traditionnel et Moderne")

# Affichage du tableau
display(styled_df)
# Out:
# <style type="text/css">
# #T_f5f96 th {
#   font-weight: bold;
#   text-align: left;
#   background-color: #f2f2f2;
#   padding: 10px;
# }
# #T_f5f96 td {
#   padding: 10px;
#   white-space: pre-wrap;
# }
# #T_f5f96 caption {
#   caption-side: top;
# }
# #T_f5f96_row0_col0, #T_f5f96_row0_col1, #T_f5f96_row0_col2, #T_f5f96_row1_col0, #T_f5f96_row1_col1, #T_f5f96_row1_col2, #T_f5f96_row2_col0, #T_f5f96_row2_col1, #T_f5f96_row2_col2, #T_f5f96_row3_col0, #T_f5f96_row3_col1, #T_f5f96_row3_col2, #T_f5f96_row4_col0, #T_f5f96_row4_col1, #T_f5f96_row4_col2, #T_f5f96_row5_col0, #T_f5f96_row5_col1, #T_f5f96_row5_col2, #T_f5f96_row6_col0, #T_f5f96_row6_col1, #T_f5f96_row6_col2 {
#   white-space: pre-wrap;
#   text-align: left;
#   padding: 10px;
# }
# </style>
# <table id="T_f5f96">
#   <caption>Comparaison entre NLP Traditionnel et Moderne</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
import pandas as pd
from IPython.display import display, HTML

# Création des données pour le tableau
data = {
    'Aspect': [
        'Traitement des Données',
        'Gestion des Ressources',
        'Performance',
        'Temps de Développement',
        'Capacités de Traitement',
        'Qualité des Résultats',
        'Évolutivité',
        'Accessibilité',
        'Tests et Debugging'  
    ],
    'NLP Traditionnel': [
        "• Limité par les règles manuelles\n• Scalabilité linéaire\n• Règles spécifiques par domaine",
        "• Principalement CPU\n• Coût proportionnel au volume\n• Maintenance manuelle",
        "• R² typique: 0.60-0.70\n• Performance limitée par règles\n• Cas ambigus problématiques",
        "• Plusieurs mois par domaine\n• Expertise linguistique requise\n• Développement séquentiel",
        "• ~1000 documents/heure\n• Analyse simple\n• Règles rigides",
        "• Précision ~70-80%\n• Cohérence limitée\n• Dépendant du domaine",
        "• Mise à jour manuelle\n• Scalabilité limitée\n• Architecture fixe",
        "• Expertise technique requise\n• Barrière d'entrée élevée\n• Integration complexe",
        "• Tests unitaires classiques\n• Debugging direct\n• Inspection manuelle simple"
    ],
    'NLP Moderne': [
        "• Traitement massif automatisé\n• Apprentissage automatique\n• Adaptation cross-domaine",
        "• Utilisation GPU/TPU\n• Économies d'échelle\n• Mise à jour par fine-tuning",
        "• R² > 0.90\n• Capture des nuances\n• Gestion intelligente ambiguïtés",
        "• Jours/semaines avec fine-tuning\n• Transfer learning\n• Développement parallèle",
        "• +100,000 documents/heure\n• Analyse complexe\n• Adaptation dynamique",
        "• Précision >90%\n• Cohérence élevée\n• Généralisation efficace",
        "• Amélioration continue\n• Scalabilité automatique\n• Architecture adaptative",
        "• Interfaces simplifiées\n• Démocratisation\n• Integration API facile",
        "• Tests comportementaux\n• Debugging par attention\n• Explicabilité complexe"
    ]
}

# Création du DataFrame
df = pd.DataFrame(data)

# Style du tableau
styles = [
    dict(selector="th", props=[("font-weight", "bold"),
                              ("text-align", "left"),
                              ("background-color", "#2c3e50"),  # Couleur foncée professionnelle
                              ("color", "white"),
                              ("padding", "12px")]),
    dict(selector="td", props=[("padding", "12px"),
                              ("white-space", "pre-wrap"),
                              ("border-bottom", "1px solid #ddd")]),
    dict(selector="caption", props=[("caption-side", "top"),
                                  ("font-size", "1.2em"),
                                  ("margin-bottom", "10px"),
                                  ("color", "#2c3e50")])
]

# Création du tableau stylisé
styled_df = df.style\
    .set_table_styles(styles)\
    .set_properties(**{
        'white-space': 'pre-wrap',
        'text-align': 'left',
        'padding': '12px',
        'background-color': '#ffffff'
    })\
    .set_caption("Impact de l'Évolution du NLP sur la Scalabilité et l'Efficacité")

# Affichage du tableau
display(styled_df)
# Out:
# <style type="text/css">
# #T_6a5d7 th {
#   font-weight: bold;
#   text-align: left;
#   background-color: #2c3e50;
#   color: white;
#   padding: 12px;
# }
# #T_6a5d7 td {
#   padding: 12px;
#   white-space: pre-wrap;
#   border-bottom: 1px solid #ddd;
# }
# #T_6a5d7 caption {
#   caption-side: top;
#   font-size: 1.2em;
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_6a5d7_row0_col0, #T_6a5d7_row0_col1, #T_6a5d7_row0_col2, #T_6a5d7_row1_col0, #T_6a5d7_row1_col1, #T_6a5d7_row1_col2, #T_6a5d7_row2_col0, #T_6a5d7_row2_col1, #T_6a5d7_row2_col2, #T_6a5d7_row3_col0, #T_6a5d7_row3_col1, #T_6a5d7_row3_col2, #T_6a5d7_row4_col0, #T_6a5d7_row4_col1, #T_6a5d7_row4_col2, #T_6a5d7_row5_col0, #T_6a5d7_row5_col1, #T_6a5d7_row5_col2, #T_6a5d7_row6_col0, #T_6a5d7_row6_col1, #T_6a5d7_row6_col2, #T_6a5d7_row7_col0, #T_6a5d7_row7_col1, #T_6a5d7_row7_col2, #T_6a5d7_row8_col0, #T_6a5d7_row8_col1, #T_6a5d7_row8_col2 {
#   white-space: pre-wrap;
#   text-align: left;
#   padding: 12px;
# ...
