# %%
from IPython.display import HTML, display

comparison_table = """
<table style="width:100%; border-collapse: collapse; border: 2px solid #ddd;">
    <tr style="background-color: #f2f2f2;">
        <th style="padding: 12px; border: 1px solid #ddd;">Critères</th>
        <th style="padding: 12px; border: 1px solid #ddd;">BERT</th>
        <th style="padding: 12px; border: 1px solid #ddd;">GPT</th>
    </tr>
    <tr>
        <td style="padding: 12px; border: 1px solid #ddd;"><b>Architecture</b></td>
        <td style="padding: 12px; border: 1px solid #ddd;">Encoder-only (bidirectionnel)</td>
        <td style="padding: 12px; border: 1px solid #ddd;">Decoder-only (unidirectionnel)</td>
    </tr>
    <tr>
        <td style="padding: 12px; border: 1px solid #ddd;"><b>Objectif Principal</b></td>
        <td style="padding: 12px; border: 1px solid #ddd;">Compréhension du texte</td>
        <td style="padding: 12px; border: 1px solid #ddd;">Génération de texte</td>
    </tr>
    <tr>
        <td style="padding: 12px; border: 1px solid #ddd;"><b>Cas d'Usage Courants</b></td>
        <td style="padding: 12px; border: 1px solid #ddd;">
            • Classification de texte<br>
            • Analyse de sentiment<br>
            • NER (Named Entity Recognition)<br>
            • Question-Answering
        </td>
        <td style="padding: 12px; border: 1px solid #ddd;">
            • Génération de texte créatif<br>
            • Completion de texte<br>
            • Dialogue conversationnel<br>
            • Traduction
        </td>
    </tr>
    <tr>
        <td style="padding: 12px; border: 1px solid #ddd;"><b>Forces</b></td>
        <td style="padding: 12px; border: 1px solid #ddd;">
            • Excellente compréhension contextuelle<br>
            • Bidirectionnalité permet une meilleure compréhension<br>
            • Performant pour l'extraction d'information
        </td>
        <td style="padding: 12px; border: 1px solid #ddd;">
            • Génération de texte fluide et cohérente<br>
            • Capacité à maintenir le contexte sur de longs textes<br>
            • Versatilité dans la génération
        </td>
    </tr>
    <tr>
        <td style="padding: 12px; border: 1px solid #ddd;"><b>Faiblesses</b></td>
        <td style="padding: 12px; border: 1px solid #ddd;">
            • Moins adapté à la génération de texte<br>
            • Limite de longueur d'entrée (512 tokens)<br>
            • Coût computationnel élevé
        </td>
        <td style="padding: 12px; border: 1px solid #ddd;">
            • Pas de vision bidirectionnelle du contexte<br>
            • Peut générer du contenu inexact<br>
            • Tendance aux hallucinations
        </td>
    </tr>
</table>
"""

# Affichage du tableau
display(HTML(comparison_table))

# Analyse des différences clés
print("\nAnalyse des différences clés :")
print("""
1. Architecture et Traitement :
   - BERT : Traitement bidirectionnel, analyse le contexte dans les deux sens
   - GPT : Traitement unidirectionnel, génère le texte de gauche à droite

2. Objectifs et Applications :
   - BERT : Optimisé pour la compréhension et l'analyse du texte
   - GPT : Conçu pour la génération fluide de contenu

3. Approche du Contexte :
   - BERT : Accès simultané à tout le contexte pour chaque token
   - GPT : Accès uniquement au contexte précédent

4. Cas d'Usage Optimaux :
   - BERT : Tâches d'analyse et de compréhension
   - GPT : Tâches de génération et de création
""")
# Out:
# <table style="width:100%; border-collapse: collapse; border: 2px solid #ddd;">
#     <tr style="background-color: #f2f2f2;">
#         <th style="padding: 12px; border: 1px solid #ddd;">Critères</th>
#         <th style="padding: 12px; border: 1px solid #ddd;">BERT</th>
#         <th style="padding: 12px; border: 1px solid #ddd;">GPT</th>
#     </tr>
#     <tr>
#         <td style="padding: 12px; border: 1px solid #ddd;"><b>Architecture</b></td>
#         <td style="padding: 12px; border: 1px solid #ddd;">Encoder-only (bidirectionnel)</td>
#         <td style="padding: 12px; border: 1px solid #ddd;">Decoder-only (unidirectionnel)</td>
#     </tr>
#     <tr>
#         <td style="padding: 12px; border: 1px solid #ddd;"><b>Objectif Principal</b></td>
#         <td style="padding: 12px; border: 1px solid #ddd;">Compréhension du texte</td>
#         <td style="padding: 12px; border: 1px solid #ddd;">Génération de texte</td>
#     </tr>
#     <tr>
# ...
